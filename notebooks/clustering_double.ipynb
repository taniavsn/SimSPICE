# %% [markdown]
# # Clustering single augmentation

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)
parent_dir1 = os.path.abspath(os.path.join(parent_dir, '..'))
sys.path.append(parent_dir1)

import numpy as np
import matplotlib.pyplot as plt
import hdbscan

import matplotlib.pyplot as plt
from lightly.loss import NTXentLoss

import simspice.utils.inverse_mapping_functions as imf
import wandb
import tqdm
from datetime import datetime

plt.rcParams['image.origin'] = 'lower'

# %%
simspice = "/d0/tvaresano/SimSPICE/"
os.environ["CUDA_VISIBLE_DEVICES"] = "2,3"

# %%
id = 'resnet_simCLR'

# %%
stacked_outputs = np.load(simspice+f'notebooks/jobs/model_outputs/stacked_outputs_double64_full_{id}.npy')

# %%
for x in [10, 20, 30]:
    for y in tqdm.tqdm([5, 10, 15]):
        clusterer = hdbscan.HDBSCAN(min_cluster_size=x, min_samples=y, metric='euclidean') # <=> cosine?
        clusterer.fit(stacked_outputs)
        labels = clusterer.labels_
        np.save(simspice+f'notebooks/jobs/clustering/{id}_minclus{x}_minsamp{y}.npy', labels)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  33%|███▎      | 1/3 [10:13<20:26, 613.12s/it]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  67%|██████▋   | 2/3 [20:46<10:24, 624.88s/it]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 100%|██████████| 3/3 [31:31<00:00, 630.49s/it]
#   0%|          | 0/3 [00:00<?, ?it/s]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  33%|███▎      | 1/3 [10:07<20:14, 607.01s/it]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  67%|██████▋   | 2/3 [20:39<10:21, 621.93s/it]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 100%|██████████| 3/3 [31:20<00:00, 626.97s/it]
#   0%|          | 0/3 [00:00<?, ?it/s]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  33%|███▎      | 1/3 [10:01<20:03, 601.78s/it]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  67%|██████▋   | 2/3 [20:27<10:16, 616.06s/it]/d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /d0/tvaresano/.conda/envs/simspice/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 100%|██████████| 3/3 [31:07<00:00, 622.54s/it]

# %%
c=0
plt.figure(figsize=(15,12), tight_layout=True)
for x in [10, 20, 30]:
    for y in [5, 10, 15]:
        c+=1
        plt.subplot(4,3,c)
        labels = np.load(simspice+f'notebooks/jobs/clustering/{id}_minclus{x}_minsamp{y}.npy')
        imf.map_clusters(labels, dataset_path=simspice+'spectra_Feb2023.nc', selected_clusters=None)
        plt.title(f"min_cluster = {x}\nmin_samples = {y}")
plt.suptitle(f'Feb23_{id}')
# Out:
# Unique Clusters: 3
# Unique Clusters: 3
# Unique Clusters: 3
# Unique Clusters: 3
# Unique Clusters: 3
# Unique Clusters: 6
# Unique Clusters: 3
# Unique Clusters: 3
# Unique Clusters: 4
# Text(0.5, 0.98, 'Feb23_Fulltrained_single64_resnet_sb128')
